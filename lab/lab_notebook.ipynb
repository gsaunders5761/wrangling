# %% [markdown]
# # Web Scraping
#
# Lots of great data is available online, but available through inconveniently formatted web pages. When this is the case, sometimes you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with and how it is used.
#
# We'll be scraping data about used cars in Charlottesville from Craigslist, particularly this page: https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0

# %% [markdown]
# We'll use the `requests` package to get web pages off the Internet and into Python. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville. To use requests, you pass a `url` for the page you want and a `header` that controls how you appear to the server to `requests.get`:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0' # The page we want to scrape
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](./src/craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](./src/craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](./src/listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tags, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.
#
# What I do is look at the rendered page, find the text I want and copy it, then search for that text in the HTML code that the computer sees. When I find the text I want, I look for the tag nearby. Here, it's `cl-static-search-result`: That's what I'll want beautifulSoup to search for.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings of the kind we want

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# Parsing the entries can be a challenge! We have to go back to what a listing looks like, and look at the tags within the listing. They're typically `div` tags with a `class` like price or location. You then have to experiment a bit with `.find` and the HTML to make sure you're getting the information you want. For each listing, the `.find` method to search within the listing record for specific information, but it's typically still wrapped in the tag. To get the real information we want, we can then use `.get_text()`. I end up using a code chunk to experiment and play with a record to make sure I'm getting as close to what I want as possible.
#
# In the code below, two more things happen. You don't need to do them in your work, but they're helpful to know about.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, if possible, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('./src/craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (61, 6)
#                                       title  price    year  \
# 0      2006 cadillac cts 107,086 miles only   2950  2006.0
# 1                                     chevy   6000     NaN
# 2  1966 chevrolet corvair corsa sport coupe   5000  1966.0
# 3   1979 oldsmobile cutlass supreme broughm   2800  1979.0
# 4                      2009 honda fit sport   3400  2009.0
#
#                                                 link      brand   age
# 0  https://charlottesville.craigslist.org/cto/d/c...   cadillac  19.0
# 1  https://charlottesville.craigslist.org/cto/d/w...      chevy   NaN
# 2  https://charlottesville.craigslist.org/cto/d/b...  chevrolet  59.0
# 3  https://charlottesville.craigslist.org/cto/d/c...    missing  46.0
# 4  https://charlottesville.craigslist.org/cto/d/c...      honda  16.0

# %% [markdown]
# With the data in and wrangled, we can now do some analysis:

# %%
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count       61.000000
# mean      9666.377049
# std      10796.992591
# min       2000.000000
# 25%       3450.000000
# 50%       6250.000000
# 75%      10950.000000
# max      62800.000000
# Name: price, dtype: float64
# count    56.000000
# mean     21.964286
# std      14.700605
# min       4.000000
# 25%      13.000000
# 50%      17.500000
# 75%      22.500000
# max      68.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                         \
#            count          mean           std      min      25%      50%
# brand
# acura        2.0   5250.000000   3181.980515   3000.0   4125.0   5250.0
# audi         1.0  11000.000000           NaN  11000.0  11000.0  11000.0
# bmw          2.0   8750.000000   1767.766953   7500.0   8125.0   8750.0
# cadillac     1.0   2950.000000           NaN   2950.0   2950.0   2950.0
# chevrolet    2.0   9750.000000   6717.514421   5000.0   7375.0   9750.0
# chevy        3.0   3966.666667   1761.628035   2900.0   2950.0   3000.0
# dodge        2.0   6875.000000   4065.863992   4000.0   5437.5   6875.0
# ford         7.0  17142.857143  15258.096992   4000.0   8250.0  13500.0
# gmc          2.0  16500.000000  13435.028843   7000.0  11750.0  16500.0
# honda        9.0   9711.111111   8211.035934   3000.0   4700.0   6500.0
# jeep         3.0   7900.000000   1429.160593   6250.0   7475.0   8700.0
# kia          1.0   2500.000000           NaN   2500.0   2500.0   2500.0
# lexus        2.0  11175.000000    318.198052  10950.0  11062.5  11175.0
# missing     15.0   8759.933333  15883.759723   2000.0   3050.0   3500.0
# mitsubishi   1.0   6800.000000           NaN   6800.0   6800.0   6800.0
# tesla        1.0  26900.000000           NaN  26900.0  26900.0  26900.0
# toyota       5.0   7880.000000   5392.309338   3000.0   4500.0   5200.0
# volkswagen   2.0   4550.000000   2757.716447   2600.0   3575.0   4550.0
#
#
#                 75%      max
# brand
# acura        6375.0   7500.0
# audi        11000.0  11000.0
# bmw          9375.0  10000.0
# cadillac     2950.0   2950.0
# chevrolet   12125.0  14500.0
# chevy        4500.0   6000.0
# dodge        8312.5   9750.0
# ford        18250.0  49500.0
# gmc         21250.0  26000.0
# honda       13000.0  29000.0
# jeep         8725.0   8750.0
# kia          2500.0   2500.0
# lexus       11287.5  11400.0
# missing      4499.5  62800.0
# mitsubishi   6800.0   6800.0
# tesla       26900.0  26900.0
# toyota      10700.0  16000.0
# volkswagen   5525.0   6500.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min    25%   50%    75%   max
# brand
# acura        2.0  15.000000   5.656854  11.0  13.00  15.0  17.00  19.0
# audi         1.0   8.000000        NaN   8.0   8.00   8.0   8.00   8.0
# bmw          2.0  16.500000   0.707107  16.0  16.25  16.5  16.75  17.0
# cadillac     1.0  19.000000        NaN  19.0  19.00  19.0  19.00  19.0
# chevrolet    2.0  47.500000  16.263456  36.0  41.75  47.5  53.25  59.0
# chevy        1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0
# dodge        2.0  26.500000   6.363961  22.0  24.25  26.5  28.75  31.0
# ford         7.0  18.000000   8.485281   8.0  12.00  17.0  22.00  33.0
# gmc          1.0  41.000000        NaN  41.0  41.00  41.0  41.00  41.0
# honda        9.0  12.555556   4.503085   4.0  11.00  13.0  15.00  19.0
# jeep         3.0  14.333333   3.214550  12.0  12.50  13.0  15.50  18.0
# kia          1.0  17.000000        NaN  17.0  17.00  17.0  17.00  17.0
# lexus        2.0  17.000000   5.656854  13.0  15.00  17.0  19.00  21.0
# missing     13.0  31.923077  21.398838   7.0  18.00  24.0  46.00  68.0
# mitsubishi   1.0  17.000000        NaN  17.0  17.00  17.0  17.00  17.0
# tesla        1.0   7.000000        NaN   7.0   7.00   7.0   7.00   7.0
# toyota       5.0  18.400000   4.878524  12.0  17.00  17.0  21.00  25.0
# volkswagen   2.0  33.000000  15.556349  22.0  27.50  33.0  38.50  44.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   0.626361 -0.177569
# log_age    -0.177569  0.348187
#            log_price   log_age
# log_price   1.000000 -0.387774
# log_age    -0.387774  1.000000

# %% [markdown]
# ## The Lab:
#
#
# 1. Pick something else on Craigslist besides used cars: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of basic EDA you'd do with it.
# 2. Get your search results of interest using `requests` and extract data from them using `beautifulSoup`, using code similar to what's above.
# 3. Wrangle your data into a dataframe and do some basic descriptions and plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# 1. I chose cds/dvds/vhs, and the fields I'm collecting are title, price, place (location), link, and format (dvd, cd, vhs, etc). I'd like to see how popular various formats are, particularly given the rise of digital media streaming, and how expensive they are.

# %%
#packages and setting up variables on webpage 

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from bs4 import BeautifulSoup as soup # HTML parser
import requests # Page requests
import re # Regular expressions
import time # Time delays
import random # Random numbers

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/ema#search=1~gallery~0~15' # The page of cds/dvds
raw = requests.get(url,headers=header) # Get page

# %%
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %%
# define format options
dvd = ['dvd', 'dvd\'s']
bluray = ['blu-ray']
vhs = ['vhs']
movie = ['movie']
cd = ['cd\'s', 'cd']  
vinyl = ['vinyl', 'record', 'album']
cassette = ['cassette', 'tape']

# %%
data = [] # We'll save our listings in this object
for k in range(len(listings)):
    title_tag = listings[k].find('div', class_='title')
    price_tag = listings[k].find('div', class_='price')
    place_tag = listings[k].find('div', class_='location')
    
    title = title_tag.get_text().lower() if title_tag else 'missing'
    price = price_tag.get_text() if price_tag else 'missing'
    place = place_tag.get_text() if place_tag else 'missing'
    link = listings[k].find(href=True)['href']
    
    # Get formats from the title string:
    words = title.split()
    format_ = []
    dvd_hits = [word for word in words if word in dvd] # Find movie words in the title
    bluray_hits = [word for word in words if word in bluray] # Find music words in the title
    vhs_hits = [word for word in words if word in vhs] # Find music words in the title
    movie_hits = [word for word in words if word in movie] # Find movie words in the title
    cd_hits = [word for word in words if word in cd] # Find music words in the title
    vinyl_hits = [word for word in words if word in vinyl] # Find music words in the title
    cassette_hits = [word for word in words if word in cassette] # Find music words in the title

    # assign format based on hits
    if len(dvd_hits) != 0:
        format_ = 'dvd'
    elif len(bluray_hits) != 0:
        format_ = 'blu-ray'
    elif len(vhs_hits) != 0:
        format_ = 'vhs'
    elif len(movie_hits) != 0:
        format_ = 'movie (unknown)'
    elif len(cd_hits) != 0:
        format_ = 'cd'
    elif len(vinyl_hits) != 0:
        format_ = 'vinyl'
    elif len(cassette_hits) != 0:
        format_ = 'cassette'
    else:
        format_ = 'other'
    data.append({'title': title, 'price': price, 'place': place, 'link': link, 'format': format_})

# %%
media = pd.DataFrame.from_dict(data)
# clean price & place variables
media['price'] = media['price'].str.replace('$','')
media['price'] = media['price'].str.replace(',','')
media['price'] = pd.to_numeric(media['price'],errors='coerce')
media['place'] = media['place'].str.replace('\n','')
media.head()
# Out:
#                                                title  price  \
# 0                      beatles original mono box set    150
# 1                         decade you were born dvd's     25
# 2              pentangle - 3 cd's like new condition     40
# 3             star wars original trilogy on vhs 1995     50
# 4  alien, aliens, and more aliens sealed blu-ray ...     50
#
#                                                place  \
# 0                          Charlottesville       ...
# 1                          Charlottesville       ...
# 2                          Charlottesville       ...
# 3                          Charlottesville       ...
# 4                          Charlottesville       ...
#
#                                                 link   format
# 0  https://charlottesville.craigslist.org/emd/d/c...    other
# 1  https://charlottesville.craigslist.org/emd/d/c...      dvd
# 2  https://charlottesville.craigslist.org/emd/d/c...       cd
# 3  https://charlottesville.craigslist.org/emd/d/c...      vhs
# 4  https://charlottesville.craigslist.org/emd/d/c...  blu-ray

# %%
media['format'].hist()
# histogram of count by media type
# Out:
# <Axes: >

# %%
sns.kdeplot(data=media, x='price', hue='format')

# KDE plot of price by media type
# results: most items are priced under $100, with a few outliers priced higher
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
media.sort_values(by='price', ascending=False).head(10)
# sort by price to find most expensive items. 
# interesting: aliens, aliens, and more aliens ?
# Out:
#                                                 title  price  \
# 0                       beatles original mono box set    150
# 29                 carl perkins autographed sun label    150
# 25                      beatles anthology dvd box set    100
# 3              star wars original trilogy on vhs 1995     50
# 4   alien, aliens, and more aliens sealed blu-ray ...     50
# 22     the famous sound of three blind mice jazz cd's     50
# 14                       bob dylan live cd collection     50
# 2               pentangle - 3 cd's like new condition     40
# 41  beatles- hard day's night, help! and sullivan ...     40
# 43  new reissue led zeppelin physical graffiti rec...     35
#
#                                                 place  \
# 0                           Charlottesville       ...
# 29                          Charlottesville       ...
# 25                          Charlottesville       ...
# 3                           Charlottesville       ...
# 4                           Charlottesville       ...
# 22                          Charlottesville       ...
# 14                          Charlottesville       ...
# 2                           Charlottesville       ...
# 41                          Charlottesville       ...
# 43                          Nelson                ...
#
#                                                  link   format  beatles  \
# 0   https://charlottesville.craigslist.org/emd/d/c...    other     True
# 29  https://charlottesville.craigslist.org/emd/d/c...    other    False
# 25  https://charlottesville.craigslist.org/emd/d/c...      dvd     True
# 3   https://charlottesville.craigslist.org/emd/d/c...      vhs    False
# 4   https://charlottesville.craigslist.org/emd/d/c...  blu-ray    False
# 22  https://charlottesville.craigslist.org/emd/d/c...       cd    False
# 14  https://charlottesville.craigslist.org/emd/d/c...       cd    False
# 2   https://charlottesville.craigslist.org/emd/d/c...       cd    False
# 41  https://charlottesville.craigslist.org/emd/d/c...    other     True
# 43  https://charlottesville.craigslist.org/emd/d/n...    vinyl    False
#
#     star wars
# 0       False
# 29      False
# 25      False
# 3        True
# 4       False
# 22      False
# 14      False
# 2       False
# 41      False
# 43      False

# %%
media['title'].str.split().explode().value_counts().head(20)
# the most common words in the titles of the listings
# observation: most common words are:
# 1. most common words in the english language, 
# 2. media types, 
# 3. 'new,' 'beatles,' 'original,' 'adult', 'rock,', 'rock'
# Out:
# title
# the         9
# and         9
# set         7
# of          6
# cd          6
# disc        5
# movies      5
# box         5
# -           5
# vhs         5
# cd's        5
# dvd         5
# new         4
# record      4
# albums      4
# beatles     3
# original    2
# adult       2
# rock,       2
# rock        2
# Name: count, dtype: int64

# %%
(pd.crosstab(media['place'],media['format'])
   .plot.bar(stacked=True)
)
# bar plot of media type by location
# Out:
# <Axes: xlabel='place'>
